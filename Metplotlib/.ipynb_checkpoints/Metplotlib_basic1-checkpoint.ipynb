# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread("image.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (380, 612, 3)

# %%
plt.imshow(img)

# %%
#plot --> RGB
#opencv --> BGR

# %%
img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)

# %%
plt.imshow(img)

# %%
gray = cv2.imread("image.jpg",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(gray,cmap="gray")

# %%
gray.shape
# Out:
# (380, 612)

# %%
small_img = cv2.resize(img,(150,150))

# %%
plt.imshow(small_img)

# %%
small_ratio = cv2.resize(img,(0,0),fx=.5,fy=.5)

# %%
plt.imshow(small_ratio)

# %%
new_img = cv2.flip(img,0)
plt.imshow(new_img)

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(img)
