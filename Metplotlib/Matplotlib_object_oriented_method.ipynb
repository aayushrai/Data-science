# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,5)

# %%
y = x**2

# %%
fig = plt.figure()
ax1 = fig.add_axes([.1,.1,.8,.8])
ax2 = fig.add_axes([.2,.5,.4,.3])
ax1.plot(x,y,"b")
ax1.set_title("larger")
ax2.plot(y,x,"r")
ax2.set_title("smaller")
# Out:
# Text(0.5, 1.0, 'smaller')

# %%
fig,axes = plt.subplots(nrows =1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title("first plot")
axes[1].plot(y,x)
axes[1].set_title("second plot")
# Out:
# Text(0.5, 1.0, 'second plot')

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000022124EF4EF0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000022124D66358>],
#       dtype=object)
