# %% [markdown]
# # IMPORT

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # READING CSV

# %%
df = pd.read_csv("churn.csv")

# %% [markdown]
# # DATA

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1        1.0               1
# 1       1   83807.86              1        0.0               1
# 2       8  159660.80              3        1.0               0
# 3       1       0.00              2        0.0               0
# 4       2  125510.82              1        1.0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2        1.0               0
# 9996      10   57369.61              1        1.0               1
# 9997       7       0.00              1        0.0               1
# 9998       3   75075.31              2        1.0               0
# 9999       4  130142.79              1        1.0               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# # DATA INFO AND DESCRIPTION

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count    9998.000000   10000.000000  9999.000000    10000.000000
# mean    76501.189526       1.530200     0.705571        0.515100
# std     62394.266511       0.581654     0.455809        0.499797
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            9998 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          9999 non-null float64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# # DATA CLEANING

# %%
df.isna()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
df.isna().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance             True
# NumOfProducts      False
# HasCrCard           True
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
# Removing balance column nan
df["Balance"].fillna(df["Balance"].mean(),inplace=True)

# %%
#balance column nan is removed
df.isna().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard           True
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
#removing nan from HasCrCard column
df["HasCrCard"].fillna(df.HasCrCard.value_counts()[1],inplace=True)

# %%
#HasCrCard column nan is removed
df.isna().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
#removing rownumber coloumn because its not essential
df.drop("RowNumber",axis=1,inplace=True)

# %%
df.drop("CustomerId",axis=1,inplace=True)

# %%
categorical_features = ["Geography","Gender","HasCrCard","IsActiveMember","Exited","Tenure"]
ROWS, COLS = 2, 3
fig, ax = plt.subplots(ROWS, COLS, figsize=(18, 18))
row, col = 0, 0
for i, categorical_feature in enumerate(categorical_features):
    if col == COLS - 1:
        row += 1
    col = i % COLS
    data=df[categorical_feature].value_counts()
    df[categorical_feature].value_counts().plot('pie', ax=ax[row, col]).set_title(categorical_feature)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='pie')` instead of `Series.plot('pie',)`.
#   # Remove the CWD from sys.path while we load stuff.

# %%
numeric_df = df.select_dtypes(exclude=['object'])
numeric_df.hist(bins=50, figsize=(20, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019713E0FC18>,
# ...
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
categorical_features = ["Geography","Gender","HasCrCard","IsActiveMember","Exited","Tenure"]
ROWS, COLS = 2, 3
fig, ax = plt.subplots(ROWS, COLS, figsize=(18, 18))
row, col = 0, 0
for i, categorical_feature in enumerate(categorical_features):
    if col == COLS - 1:
        row += 1
    col = i % COLS
    df[categorical_feature].value_counts().plot('bar', ax=ax[row, col]).set_title(categorical_feature)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   if __name__ == '__main__':

# %%
import seaborn as sns
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df.corr(), annot = True,linewidths = .5,square = True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (9.0, 0.0)

# %%
numeric_features = numeric_df.columns.values
ROWS, COLS = 3,3
fig, ax = plt.subplots(ROWS, COLS, figsize=(18, 18))
row, col = 0, 0
for i,numeric  in enumerate(numeric_features):
    if col == COLS - 1:
        row += 1
    col = i % COLS
    df[numeric].plot(kind='box', ax=ax[row, col])

# %%
df.plot(kind='scatter',x="EstimatedSalary",y="Age")

# %%
df.columns
# Out:
# Index(['Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')
